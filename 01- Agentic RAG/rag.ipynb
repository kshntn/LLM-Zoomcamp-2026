# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
assistant.rag("What is RAG?")
# Out:
# 'RAG stands for **Retrieval-Augmented Generation**.\n\nIt is a setup where the model first **retrieves relevant information** from documents or another knowledge source, and then uses that information to **generate** an answer.'
